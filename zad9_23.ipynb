# %%
import turtle
turtle.fd(120)
turtle.lt(120)
turtle.fd(120)
turtle.lt(120)
turtle.fd(120)
turtle.pu()
turtle.goto(60,-20)
turtle.write('a', move=False)
turtle.goto(110,50)
turtle.write('a', move=False)
turtle.goto(10,50)
turtle.write('a', move=False)
turtle.goto(0,0)
turtle.done()
