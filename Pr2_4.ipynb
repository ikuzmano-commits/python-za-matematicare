# %%
x=7
if x==0:
    print('x je nula')  
elif x>0:                   #elif– skraćeno od else if
    print('x je veći od 0')
else:                   #ako koristimo elif, grananje mora završavati s else
    print('x je manji od 0')
