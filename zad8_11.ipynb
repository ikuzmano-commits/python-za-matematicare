# %%
class krivulje:
    def __init__(self, a11,a12,a22,a1,a2,a0):
        self.a11=a11
        self.a12=a12
        self.a22=a22
        self.a1=a1
        self.a2=a2
        self.a0=a0
    def identifikacija(self):
        if self.a11*self.a22-self.a12**2>0:
            print('dani skup je elipsa ili skup koji sadrzi samo jednu tocku ili prazan skup')
        if self.a11*self.a22-self.a12**2<0:
            print('skup je hiperbola ili unija dvaju pravaca koji se sijeku')
        if self.a11*self.a22-self.a12**2==0:
            print('skup je parabola ili unija dvaju paralelnih pravaca ili jedan pravac ili prazan skup')
    def __eq__(self,k2):
        det1=self.a11*self.a22-self.a12**2
        det2=k2.a11*k2.a22-k2.a12**2
        if(det1>0 and det2>0):
            return True
        elif(det1<0 and det2<0 ):
            return True
        elif(det1==0 and det2==0 ):
            return True
        else:
            return False
        #return ((det1>0 and det2>0) or (det1<0 and det2<0 ) or (det1==0 and det2==0 ))
class nulslucaj(krivulje):
    def __init__(self,a1,a2,a0):
        super(nulslucaj,self).__init__(0,0,0,a1,a2,a0)
    def __str__(self):
        return f"{self.a1}x1+{self.a2}x2+{self.a0}=0"

# %%
k1=krivulje(1,2,3,2,1,2)
k1.identifikacija()
k2=krivulje(1,3,3,2,1,1)
k2.identifikacija()
print(k1==k2)
n1=nulslucaj(2,1,3)
n1.identifikacija()
print(n1)
