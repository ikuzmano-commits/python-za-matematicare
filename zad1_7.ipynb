# %%
# Komponente vektora
v1 = 2
v2 = 3
v3 = 4

# %%
# Izračun norme
norma = (v1**2 + v2**2 + v3**2)**0.5

# %%
# Ispis rezultata - {norma:.6f} omogućava ispis 6 decimalnih mjesta  
print(f"Norma vektora {v1}i+{v2}j+{v3}k je {norma:.6f}")
