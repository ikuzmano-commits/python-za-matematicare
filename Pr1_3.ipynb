# %%
punoljetan = eval(input("Unesite vrijednost za punoljetan (True/False): "))
# eval pretvara string 'True' ili 'False' u logičku vrijednost.
print(f'Punoljetan: {punoljetan}')
print(f'Tip varijable: {type(punoljetan)}')
