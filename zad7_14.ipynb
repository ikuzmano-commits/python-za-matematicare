# %%
# naredba !wget koristi se za preuzimanje datoteke s interneta
# ovdje preuzimamo datoteku vrijednosti.txt s GitHub repozitorija u Colab radni direktorij
# !wget https://raw.githubusercontent.com/ikuzmano-commits/python-za-matematicare/main/vrijednosti.txt

def izracunaj(datoteka):
    rez = []

    try:
        with open(datoteka, 'r') as dat:
            for i, linija in enumerate(dat, start=1):
                try:
                    x = float(linija.strip())
                    vrijednost = 100 / x
                    rez.append(vrijednost)

                except ValueError:
                    print(f"Redak {i}: neispravan unos ('{linija.strip()}').")

                except ZeroDivisionError:
                    print(f'Redak {i}: dijeljenje s nulom nije dozvoljeno.')

    except FileNotFoundError:
        print(f"Greška: datoteka '{datoteka}' ne postoji.")
        return []

    return rez


# poziv funkcije
rez = izracunaj('vrijednosti.txt')
print('Uspješno izračunati rezultati:', rez)
# Out:
# --2026-04-24 11:47:57--  https://raw.githubusercontent.com/ikuzmano-commits/python-za-matematicare/main/vrijednosti.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27 [text/plain]
# Saving to: ‘vrijednosti.txt.2’
#
# vrijednosti.txt.2   100%[===================>]      27  --.-KB/s    in 0s
#
# 2026-04-24 11:47:57 (1.14 MB/s) - ‘vrijednosti.txt.2’ saved [27/27]
#
# Redak 3: neispravan unos ('abc').
# Redak 7: dijeljenje s nulom nije dozvoljeno.
# Uspješno izračunati rezultati: [10.0, 50.0, 11.11111111111111, 20.0, 5.0, 2.0]
