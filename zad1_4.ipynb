# %%
from datetime import datetime

ime = input('Unesi ime: ')
god_rodenja = int(input('Unesi godinu rođenja: '))

# Dohvaćanje trenutnog datuma i ekstrakcija godine
trenutna_godina = datetime.now().year
# Out:
# Unesi ime: Ivana
# Unesi godinu rođenja: 1982

# %%
print(f"{ime} ima {trenutna_godina - god_rodenja} godina.")
# Out:
# Ivana ima 44 godina.
