# %%
ime = input('Unesi ime: ')
god1 = int(input('Unesi godinu rođenja: '))
god2 = int(input('Unesi trenutnu kalendarsku godinu: '))

# %%
print(f"{ime} ima {god2 - god1} godina.") # računske operacije mogu se izvoditi i u ispisu
