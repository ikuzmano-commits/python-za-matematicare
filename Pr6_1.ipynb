# %%
import sympy as sp

# %%
x = sp.symbols('x')

# %%
f = x**2 -3*x - 10
g = (x - 1)*(x + 2)

# %%
print("f =", f)
print("g =", g)

# %%
print("expand(g) =", sp.expand(g))
print("factor(f) =", sp.factor(f))
