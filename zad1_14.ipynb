# %%
# Unos brojeva
a = int(input("Unesite broj a: "))
b = int(input("Unesite broj b: "))
c = int(input("Unesite broj c: "))

# %%
# Provjera i ispis rezultata
trokut = (a + b > c) and (a + c > b) and (b + c > a)
print(trokut)
