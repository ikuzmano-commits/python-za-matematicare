# %%
# primjer rječnika čije su vrijednosti različitih tipova
student = {
    "ime": "Ana",
    "godine": 21,
    "redovan": True,
    "ocjene": [5, 4, 5, 3],
    "kontakt": {"email": "ana@example.com", "grad": "Zagreb"}
}

# %%
print(student["ime"])
print(student["ocjene"])
print(student["kontakt"]["email"])
