# %%
n=int(input('Zadaj prirodan broj:'))
br=0 #postavimo brojač znamenki na 0
broj=n

# %%
while broj>0:
    broj//=10 #podijeli varijablu broj s 10, koristeći cjelobrojno dijeljenje, i spremi rezultat natrag u broj
    br+=1
print(f'Broj {n} ima {br} znamenki.')
