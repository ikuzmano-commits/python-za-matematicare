# %%
# Koordinate točke
x = 2
y = 3

# %%
# Granice pravokutnika (x1, y1) - donji lijevi kut, (x2, y2) - gornji desni kut
x1, y1 = 0, 0
x2, y2 = 4, 5
r = 3 # Radijus kruga

# %%
# Logički izraz
rezultat = ((x1 <= x <= x2) and (y1 <= y <= y2)  and (x**2 + y**2 > r**2))
print(rezultat)
