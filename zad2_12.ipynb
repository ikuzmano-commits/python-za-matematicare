# %%
n = int(input("Unesite prirodni broj: "))

# %%
# provjera djelitelja broja n
print(f"Djelitelji broja {n} su:")

# %%
# petlja koja prolazi kroz sve brojeve od 1 do n
for i in range(1, n + 1):
    if n % i == 0:
        print(i)
