# %%
A = {1, 2, 3, 3, 4, 5}
print(A)        # automatski uklanja duplikate → {1, 2, 3, 4, 5}

# %%
B = set([3, 4, 5, 6])  # skup se može stvoriti i iz liste
print(B)

# %%
print(3 in A)   # provjera pripadnosti → True
print(7 in A)   # → False
