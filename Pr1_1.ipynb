# %%
#Pridruživanje vrijednosti varijabli. Tip varijable ne mora se eksplicitno navoditi. 
a=5              #varijabla tipa int
b=3.5            #varijabla tipa float
c='kaktus'       #varijabla tipa string, koriste se jednostruki ili dvostruki navodnici
d=True           #varijabla tipa bool

# %% [markdown]
# Unos vrijednosti varijable s tipkovnice: ime_varijable=tip_varijable(input('Poruka'))

# %%
#unos vrijednosti int varijable s tipkovnice
a1=int(input('Unesi neki cijeli broj:'))

# %%
#unos vrijednosti float varijable s tipkovnice      
b1=float(input('Unesi neki realni broj:'))

# %%
#unos vrijednosti string varijable s tipkovnice
#!(string je default tip za naredbu input)
c1=input('Unesi neki niz znakova:')
