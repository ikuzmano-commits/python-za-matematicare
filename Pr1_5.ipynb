# %%
rijec1 = 'prva'
rijec2 = 'druga'

# %%
# Spajanje riječi pomoću +
spojeno = rijec1 +  rijec2
print("Spojeno:", spojeno) #rezultat će biti prvadruga
spojeno2 = rijec1 + " " + rijec2
print("Spojeno2:", spojeno2) #rezultat će biti prva druga
# Ponavljanje prve riječi pomoću *
ponovljeno = rijec1 * 3
print("Ponavljeno:", ponovljeno) #rezultat će biti prvaprvaprva
