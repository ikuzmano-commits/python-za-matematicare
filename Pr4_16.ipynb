# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# %%
print(A | B)   # unija → {1, 2, 3, 4, 5, 6}
print(A & B)   # presjek → {3, 4}
print(A - B)   # razlika → {1, 2}
print(A ^ B)   # simetrična razlika → {1, 2, 5, 6}
