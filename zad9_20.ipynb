# %%
import turtle
turtle.goto(-100,0)
turtle.colormode(255)
turtle.pencolor(255,200,0)
turtle.pensize(40)
turtle.fd(100)
turtle.pencolor(0,255,200)
turtle.fd(100)
turtle.pencolor(200,0,200)
turtle.fd(100)

# %%
turtle.done()
