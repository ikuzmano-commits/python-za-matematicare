# %%
broj = 12

# %%
if broj % 2 == 0:
    if broj % 3 == 0:
        print("Broj je djeljiv s 2 i s 3.")
    else:
        print("Broj je paran, ali nije djeljiv s 3.")
else:
    print("Broj je neparan.")
