# %%
x=7
if x>3:
    print('x je veći od 3')   #ako x nije veći od 3, ne izvršava se ništa
x=10

# %%
if (x%2==0 and x%3==0):
    print (x, 'je djeljiv s 6')

# %%
if (x%2==0 or x%3==0):
    print (x, 'je mozda djeljiv s 6')

# %%
if (not(x%2==0 and x%3==0)):
    print (x, 'nije djeljiv s 6')
