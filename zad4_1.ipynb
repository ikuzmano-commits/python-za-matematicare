# %%
lista = [2, 4, 5, 6, 8]

# %%
# 1. način – pomoću privremene varijable
a = lista[0]
lista[0] = lista[-1]
lista[-1] = a
print(lista)

# %%
# 2. način – kraći Pythonovski zapis (bez pomoćne varijable)
lista = [2, 4, 5, 6, 8]
lista[0], lista[-1] = lista[-1], lista[0]
print(lista)
