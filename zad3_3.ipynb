# %%
def potencija3(broj):
    while(broj%3==0):
        broj=broj//3
    if(broj==1):    
        return True
    else:
        return False

# %%
print(potencija3(5))
print(potencija3(9))

# %%
#drugi način
def potencija3b(broj):
    import math
    pot=math.log(broj,3)
    if(int(pot)==pot):    
        return True
    else:
        return False

# %%
print(potencija3b(5))
print(potencija3b(9))
