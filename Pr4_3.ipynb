# %%
lista = ['prvi', 'a', 4, -4.6, True]

# %%
print(3 in lista)   # provjerava nalazi li se broj 3 u listi (vraća True ili False)

# %%
if 4 in lista:
    print('Broj 4 je u listi na indeksu', lista.index(4))   # dohvat indeksa elementa 4
