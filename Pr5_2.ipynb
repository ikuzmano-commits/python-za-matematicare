# %%
import numpy as np

# %%
A_list = [[1, 2],
[3, 4]]

# %%
A_np = np.array([[1, 2],
[3, 4]])

# %%
print("A_list + A_list =", A_list + A_list) # spajanje listi
print("A_np + A_np =", A_np + A_np) # zbrajanje matrica
