# %%
broj=0 # postavimo početnu vrijednost broja različitu od 5
zbroj=0 # postavimo početnu vrijednost zbroja

# %%
while broj!=5: 
    broj=int(input('Unesi broj: ')) 
    if broj%3==0 or broj%7==0: # projvera je li broj djeljiv s 3 ili sa 7 
        zbroj+=broj
print(f'Zbroj učitanih brojeva koji su djeljivi s 3 ili 7 je {zbroj}.')
