# %%
ime=input('Upišite Vaše ime:')     #od korisnika tražimo da unese svoje ime
godine=int(input('Upišite koliko imate godina:'))   #zadajemo tip podatka koji tražimo od korisnika, varijabla godine je tipa int
print(f"{ime} ima {godine} godina.") #ispis pomoću f-stringa
