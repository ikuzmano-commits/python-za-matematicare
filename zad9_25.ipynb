# %%
import turtle
kornjaca=turtle.Turtle()
turtle.colormode(255)
kornjaca.speed(20)

# %%
for i in range(18):
    kornjaca.pencolor(255-5*i, 0+5*i,i)
    for k in range(4):
       kornjaca.fd(100)
       kornjaca.lt(90)
    kornjaca.rt(360/18)
turtle.done()
