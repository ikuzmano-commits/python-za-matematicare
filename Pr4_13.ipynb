# %%
t = ('a', 'b', 'c')     # n-torka
l = list(t)             # pretvaranje n-torke u listu
print(l)

# %%
l.append('d')           # dodavanje novog elementa u listu
t = tuple(l)            # ponovno pretvaranje liste u n-torku
print(t)
