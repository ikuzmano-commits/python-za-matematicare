# %%
# naredba !wget koristi se za preuzimanje datoteke s interneta
# ovdje preuzimamo datoteku pr1.txt s GitHub repozitorija u Colab radni direktorij
# !wget https://raw.githubusercontent.com/ikuzmano-commits/python-za-matematicare/main/pr1.txt

# %%
dat = open('pr1.txt', 'r')
dat.seek(4) # pomaknemo se sa pokazivačem na 4. znak u datoteci
print(dat.readline())   # ispisuje red iz datoteke počevši od tog mjesta
print(dat.tell()) #ispisuje se trenutni položaj pokazivača
dat.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1558512216.py in <cell line: 0>()
# ----> 1 dat = open('pr1.txt', 'r')
#       2 dat.seek(4) # pomaknemo se sa pokazivačem na 4. znak u datoteci
#       3 print(dat.readline())   # ispisuje red iz datoteke počevši od tog mjesta
#       4 print(dat.tell()) #ispisuje se trenutni položaj pokazivača
#       5 dat.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pr1.txt'
