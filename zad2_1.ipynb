# %%
vjerojatnost=float(input('Unesi vjerojatnost kiše:'))

# %%
if vjerojatnost<0 or vjerojatnost>1:
    print('Nije dobar unos!')
elif vjerojatnost>=0.5:
        print('Ponesi kišobran!')
else:
    print('Neće padati kiša.')
