# %%
def sumazn(n):
    if(n>999 and n<10000):
        d=n%10
        n=n//10
        c=n%10
        n=n//10
        b=n%10
        a=n//10
        suma=a+b+c+d
        if(suma>10):
            return 'Suma je veca od 10'
        elif(suma==10):
            return 'Suma je 10'
        else:
            return 'Suma je manja od 10'
    else:
        print('Broj nije cetveroznamenkast')

# %%
print(sumazn(1234))
