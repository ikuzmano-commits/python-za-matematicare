# %%
a = [1, 2, 3, 4, 5]

# %%
# klasičan način – korištenjem petlje
b = []
for x in a:
    b.append(x + 3)    # iz liste a dobivamo listu b čiji su elementi uvećani za 3
print(b)

# %%
# kraći i elegantniji način – pomoću list comprehension
b1 = [x + 3 for x in a]
print(b1)
