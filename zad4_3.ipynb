# %%
# početna lista brojeva
lista1 = [1, 2, 3, 5, 6, 8, 9, 11, 12]

# %%
# nova lista u koju pohranjujemo kvadrate parnih brojeva iz lista1
lista2 = []

# %%
for k in lista1:
    if k % 2 == 0:
        lista2.append(k**2)

# %%
print(lista2)
