# %%
import numpy as np

# %%
def ekstremiStupaca(matrica):
    (m,n) = matrica.shape
    for i in range(n):
        v = matrica[:,i]
        print(v)
        print('min:',v.min())
        print('max:',v.max())

# %%
M = np.random.randint(4,16,size=(4,3))
print(M)
ekstremiStupaca(M)
