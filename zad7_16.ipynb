# %%
# naredba !wget koristi se za preuzimanje datoteke s interneta
# ovdje preuzimamo datoteku vrijednosti.txt s GitHub repozitorija u Colab radni direktorij
# !wget https://raw.githubusercontent.com/ikuzmano-commits/python-za-matematicare/main/vrijednosti.txt

import math

dat = "vrijednosti.txt"

try:
    f = open(dat, "r")
except FileNotFoundError:
    raise FileNotFoundError("Datoteka 'vrijednosti.txt' ne postoji.")

for linija in f:
    linija = linija.strip()

    try:
        # provjera praznog retka
        if linija == "":
            raise ValueError("Prazan redak u datoteci.")

        # pokušaj pretvorbe u broj
        x = float(linija)

        # provjera negativnog broja
        if x < 0:
            raise ValueError(f"Negativan broj nije dopušten: {x}")

        rezultat = math.sqrt(x)
        print(f"f(x) = sqrt({x}) = {rezultat}")

    except ValueError as e:
        print(f"Greška: {e}")

f.close()
# Out:
# --2026-04-24 11:51:02--  https://raw.githubusercontent.com/ikuzmano-commits/python-za-matematicare/main/vrijednosti.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27 [text/plain]
# Saving to: ‘vrijednosti.txt’
#
# vrijednosti.txt     100%[===================>]      27  --.-KB/s    in 0s
#
# 2026-04-24 11:51:02 (1.24 MB/s) - ‘vrijednosti.txt’ saved [27/27]
#
# f(x) = sqrt(10.0) = 3.1622776601683795
# f(x) = sqrt(2.0) = 1.4142135623730951
# Greška: could not convert string to float: 'abc'
# f(x) = sqrt(9.0) = 3.0
# f(x) = sqrt(5.0) = 2.23606797749979
# f(x) = sqrt(20.0) = 4.47213595499958
# f(x) = sqrt(0.0) = 0.0
# f(x) = sqrt(50.0) = 7.0710678118654755
