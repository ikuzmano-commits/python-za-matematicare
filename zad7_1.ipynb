# %%
# naredba !wget koristi se za preuzimanje datoteke s interneta
# ovdje preuzimamo datoteke s GitHub repozitorija u Colab radni direktorij
# !wget https://raw.githubusercontent.com/ikuzmano-commits/python-za-matematicare/main/brojevi.txt
# !wget https://raw.githubusercontent.com/ikuzmano-commits/python-za-matematicare/main/rezultati.txt

# %%
dat1=open('brojevi.txt','r') # otvaramo datoteku za čitanje
dat2=open('rezultati.txt','w') # izlazna datoteka u koju ćemo moći upisivati tekst

# %%
red1=dat1.readline() #prvi red
dat2.write(red1)

# %%
red2=dat1.readline() #drugi red

# %%
red3=dat1.readline() #treći red
dat2.write(red3)

# %%
dat1.close()
dat2.close()
