# %%
def f1n(x):
    if(isinstance(x,int) or isinstance(x,float)):
        return x+5
    else:
        return('Niste unijeli broj')   #moglo je ići i print, onda bi se poruka ispisala i vratilo None, ovako se  vraća poruka

# %%
print(f1n('a'))

# %%
print(f1n(4))
