# %%
# Primjer:
imena = ['Suzana', 'Luka', 'Krešo']
prezimena = ['Suzić', 'Perić', 'Krešić']

# %% [markdown]
# želimo dobiti rječnik:
# {'Suzana': 'Suzić', 'Luka': 'Perić', 'Krešo': 'Krešić'}

# %%
# Rješenje:
rjecnik = {ime: prezime for ime, prezime in zip(imena, prezimena)}
print(rjecnik)
