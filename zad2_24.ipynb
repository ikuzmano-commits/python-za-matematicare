# %%
import random
a=random.randint(1, 20)
print(a)
p=input('n=')
if int(p)==a:
    print('Pogodili ste.')
else:
    if int(p)<a:
        print('Premala vrijednost.')
    else:
        print('Prevelika vrijednost.')
# Out:
# 20
# n=3
# Premala vrijednost.
