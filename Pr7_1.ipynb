# %%
dat1=open('pr1.txt','w') # otvaramo (kreiramo) datoteku pod nazivom pr1.txt za pisanje, dat1 je ime nastalog objakta kojim pristupamo za rad sa tom datotekom 
dat1.write('Zapis u datoteku\n Drugi red zapisa')
dat1.close() # prekid veze između programa i datoteke na disku
